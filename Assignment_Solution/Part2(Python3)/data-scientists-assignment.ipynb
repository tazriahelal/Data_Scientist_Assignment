# %% [markdown]
# <h1 style='background:#867070; border:0; color:white'><center>Assignment Part 2: Python</center></h1>

# %% [markdown]
# ---
# # 1. **Separated the sheet 1 data in a new excel sheet.**
# ---
#
# ---
# # 2. **Convert the excel file to CSV.**
# ---
# ### Here is the File Link:
#
# ## [Dataset in CSV File](https://drive.google.com/file/d/1qThEM73BndSqk5YJ6wlbys-zaAEaVcCq/view?usp=sharing)(Click Here)

# %% [markdown]
# <h1 style='background:#867070; border:0; color:white'><center>Libraries</center></h1>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.cluster import KMeans

# %% [markdown]
# ---
# # 3. **Load The CSV File**
# ---

# %%
df = pd.read_csv('../input/assignmentdata/AssignmentCSV.csv')

# %%
df
# Out:
#          ID Customer Name    Division Gender MaritalStatus  Age  Income
# 0   BU79786     Christine       Dhaka      F       Married   45   56274
# 1   QZ44356         Susan    Rajshahi      F        Single   46       0
# 2   AI49188      Margaret      Khulna      F       Married   39   48767
# 3   WW63253         David    Barishal      M       Married   41       0
# 4   HB64268         Peter  Mymensingh      M        Single   40   43836
# 5   OC83172        Judith      Sylhet      F       Married   46   62902
# 6   XZ87318      Jennifer      Khulna      F       Married   26   55350
# 7   CF85061       Michael    Barishal      M        Single   38       0
# 8   DY87989          John  Mymensingh      M      Divorced   45   14072
# 9   BQ94931          Mary      Sylhet      F       Married   41   28812
# 10  SX51350       Stephen     Rangpur      M        Single   50       0
# 11  VQ65197     Elizabeth  Chattogram      F       Married   42       0
# ...

# %% [markdown]
# ### To know the shape

# %%
df.shape
# Out:
# (50, 7)

# %% [markdown]
# ---
# # 4. **Get rid of the column ID from the data frame.**
# ---

# %%
df.drop('ID', axis=1, inplace=True)

# %% [markdown]
# ### After removing ID column we have only 6 columns now

# %%
df.shape
# Out:
# (50, 6)

# %%
df
# Out:
#    Customer Name    Division Gender MaritalStatus  Age  Income
# 0      Christine       Dhaka      F       Married   45   56274
# 1          Susan    Rajshahi      F        Single   46       0
# 2       Margaret      Khulna      F       Married   39   48767
# 3          David    Barishal      M       Married   41       0
# 4          Peter  Mymensingh      M        Single   40   43836
# 5         Judith      Sylhet      F       Married   46   62902
# 6       Jennifer      Khulna      F       Married   26   55350
# 7        Michael    Barishal      M        Single   38       0
# 8           John  Mymensingh      M      Divorced   45   14072
# 9           Mary      Sylhet      F       Married   41   28812
# 10       Stephen     Rangpur      M        Single   50       0
# 11     Elizabeth  Chattogram      F       Married   42       0
# 12          Mark       Dhaka      M       Married   50   77026
# 13          Paul    Rajshahi      M       Married   39   99845
# ...

# %% [markdown]
# ### Checking missing values

# %%
missing_values = df.isnull().sum()

# %%
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  Customer Name    0
# Division         0
# Gender           0
# MaritalStatus    0
# Age              0
# Income           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# ---
# # 5. **Encode the data to have similar values. Here I am using Label Encoder**
# ---

# %%
categorical_columns = ['Customer Name', 'Division', 'Gender', 'MaritalStatus']
label_encoder = LabelEncoder()
for column in categorical_columns:
    df[column] = label_encoder.fit_transform(df[column])

# %% [markdown]
# ---
# # 6. **Now use K-means clustering based on their divisions**
# ---

# %%
features = ['Division', 'Gender', 'MaritalStatus', 'Age', 'Income']

# Create a subset of the data with only the selected features
subset = df[features]

# Perform K-means clustering
num_clusters = len(df['Division'].unique())  # Number of unique divisions
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(subset)

# Add the cluster labels to the DataFrame
df['Cluster'] = kmeans.labels_

# View the resulting DataFrame
print(df)
# Out:
#     Customer Name  Division  Gender  MaritalStatus  Age  Income  Cluster
# 0               7         2       0              1   45   56274        2
# 1              45         5       0              2   46       0        3
# 2              30         3       0              1   39   48767        2
# 3              10         0       1              1   41       0        3
# 4              37         4       1              2   40   43836        6
# 5              23         7       0              1   46   62902        5
# 6              21         3       0              1   26   55350        2
# 7              33         0       1              2   38       0        3
# 8              22         4       1              0   45   14072        1
# 9              32         7       0              1   41   28812        4
# 10             43         6       1              2   50       0        3
# 11             12         1       0              1   42       0        3
# ...
